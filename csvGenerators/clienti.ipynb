# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import random

# %%
persone = pd.read_csv('persone_finali.csv')

# %%
nTessera=[]
saldoPunti=[]
for i in range(0,len(persone)-1):
    nTessera.append(i+30)
    saldoPunti.append(random.randint(0, 9000))

# %%
clienti=pd.DataFrame()
clienti['nTessera']=nTessera
clienti['saldoPunti']=saldoPunti
clienti['persona']=persone['codF']
clienti
# Out:
#     nTessera  saldoPunti           persona
# 0         30        4337  DVDRNI57T41F205L
# 1         31        3295  BCCDRT73M11F205V
# 2         32        3633  GRCGTT66H54F205V
# 3         33        5652  GLLMRN93D46F205G
# 4         34        8390  CNTVRN80T31F205D
# 5         35        4419  LCCRME59R11F205A
# 6         36        8487  FRRMTN67T58F205E
# 7         37        7439  DLLSVT55L69F205L
# 8         38        3243  SGSLSE62T23F205Q
# 9         39        3532  DLLLVI96D46F205X
# 10        40        5030  BLLNNF88L04F205M
# 11        41        6017  GRCLVE91D07F205B
# 12        42        4635  LFNPNC99E12F205E
# 13        43         722  TRVRFN52D12F205F
# 14        44        5509  PGNSLL68S46F205J
# 15        45        7614  PGNMRN73E16F205A
# 16        46        5633  MLNCCT57E59F205X
# 17        47        7198  MRNRRT65T02F205F
# 18        48        6200  SBBFDR51A57F205Y
# 19        49        8893  NDRBTE69C13F205G
# 20        50        4793  NCCGRD57A08F205D
# ...

# %%
clienti.to_csv('clienti.csv',index=False)
