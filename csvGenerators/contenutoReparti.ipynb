# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import random

# %%
contiene=pd.DataFrame()
contiene['idBatch']=[]
contiene['supermercatoReparto']=[]
contiene['nomeReparto']=[]
contiene['prodotto']=[]
contiene['dataScadenza']=[]
contiene
# Out:
# Empty DataFrame
# Columns: [idBatch, supermercatoReparto, nomeReparto, prodotto, dataScadenza]
# Index: []

# %%
products = pd.read_csv('products.csv')
products
# Out:
#                       Categoria       ID  \
# 0                 Frutta fresca  5382198
# 1                 Frutta fresca  5385170
# 2           Insalate e radicchi  5381634
# 3                Verdura fresca  5391756
# 4                 Verdura cotta  5837556
# 5                         Pesce  5386477
# 6                         Sushi  5735522
# 7                    Fishburger  5772507
# 8                   Hamburgeria  5745336
# 9                   Hamburgeria  5534682
# 10                      Pollame  5428255
# 11                      Pollame  5388593
# 12                        Burro  5419992
# 13                         Uova  5377561
# 14                         Uova  5520562
# 15                     Grissini  5561086
# 16                   Panetteria  5383546
# 17                  Pasticceria  5410134
# 18                     Insalate  5722897
# 19                 Pasta fresca  5527406
# 20                 Pasta fresca  5515756
# 21                       Gelati  5731069
# ...

# %%
inizioIdBatch=1001
idsBatch=[]
for i in range(0, len(products)):
    idsBatch.append(inizioIdBatch+i)

# %%
quantita=[]
for i in range(0, len(products)):
    quantita.append(random.randint(0,300))

# %%
contiene['idBatch']=idsBatch;
contiene['prodotto']=products['ID']
contiene['supermercatoReparto']='02N120MI'
contiene['nomeReparto']=products['Reparto']
contiene['qta']=quantita
contiene
# Out:
#     idBatch supermercatoReparto                   nomeReparto  prodotto  \
# 0      1001            02N120MI              Frutta e verdura   5382198
# 1      1002            02N120MI              Frutta e verdura   5385170
# 2      1003            02N120MI             Frutta e verdura    5381634
# 3      1004            02N120MI              Frutta e verdura   5391756
# 4      1005            02N120MI              Frutta e verdura   5837556
# 5      1006            02N120MI                 Pesce e sushi   5386477
# 6      1007            02N120MI                 Pesce e sushi   5735522
# 7      1008            02N120MI                 Pesce e sushi   5772507
# 8      1009            02N120MI                    Macelleria   5745336
# 9      1010            02N120MI                    Macelleria   5534682
# 10     1011            02N120MI                    Macelleria   5428255
# 11     1012            02N120MI                    Macelleria   5388593
# ...

# %%
contiene.to_csv('contenutoReparti.csv',index=False)

# %%
contiene = pd.read_csv('contenutoReparti.csv')
contiene
# Out:
#     idBatch supermercatoReparto             nomeReparto  prodotto  \
# 0      1001            02N120MI       Frutta e Verduraa   5382198
# 1      1002            02N120MI       Frutta e Verduraa   5385170
# 2      1003            02N120MI       Frutta e Verduraa   5381634
# 3      1004            02N120MI       Frutta e Verduraa   5391756
# 4      1005            02N120MI       Frutta e Verduraa   5837556
# 5      1006            02N120MI           Pesce e Sushi   5386477
# 6      1007            02N120MI           Pesce e Sushi   5735522
# 7      1008            02N120MI           Pesce e Sushi   5772507
# 8      1009            02N120MI              Macelleria   5745336
# 9      1010            02N120MI              Macelleria   5534682
# 10     1011            02N120MI              Macelleria   5428255
# 11     1012            02N120MI              Macelleria   5388593
# 12     1013            02N120MI               Latticini   5419992
# ...

# %%
inizioIdBatch=1054
idsBatch=[]
for i in range(0, len(products)):
    idsBatch.append(inizioIdBatch+i)

# %%
contiene['idBatch']=idsBatch;
contiene
# Out:
#     idBatch supermercatoReparto             nomeReparto  prodotto  \
# 0      1054            02N120MI       Frutta e Verduraa   5382198
# 1      1055            02N120MI       Frutta e Verduraa   5385170
# 2      1056            02N120MI       Frutta e Verduraa   5381634
# 3      1057            02N120MI       Frutta e Verduraa   5391756
# 4      1058            02N120MI       Frutta e Verduraa   5837556
# 5      1059            02N120MI           Pesce e Sushi   5386477
# 6      1060            02N120MI           Pesce e Sushi   5735522
# 7      1061            02N120MI           Pesce e Sushi   5772507
# 8      1062            02N120MI              Macelleria   5745336
# 9      1063            02N120MI              Macelleria   5534682
# 10     1064            02N120MI              Macelleria   5428255
# 11     1065            02N120MI              Macelleria   5388593
# 12     1066            02N120MI               Latticini   5419992
# ...

# %%
contiene.to_csv('contenutoReparti.csv',index=False)
