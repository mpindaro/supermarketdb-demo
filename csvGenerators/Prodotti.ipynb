# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import random

# %%
products = pd.read_csv('products.csv')
products
# Out:
#                       Categoria       ID  \
# 0                 Frutta fresca  5382198
# 1                 Frutta fresca  5385170
# 2           Insalate e radicchi  5381634
# 3                Verdura fresca  5391756
# 4                 Verdura cotta  5837556
# 5                         Pesce  5386477
# 6                         Sushi  5735522
# 7                    Fishburger  5772507
# 8                   Hamburgeria  5745336
# 9                   Hamburgeria  5534682
# 10                      Pollame  5428255
# 11                      Pollame  5388593
# 12                        Burro  5419992
# 13                         Uova  5377561
# 14                         Uova  5520562
# 15                     Grissini  5561086
# 16                   Panetteria  5383546
# 17                  Pasticceria  5410134
# 18                     Insalate  5722897
# 19                 Pasta fresca  5527406
# 20                 Pasta fresca  5515756
# 21                       Gelati  5731069
# ...

# %%
prodotti=pd.DataFrame()
prodotti['id']=products['ID']
prodotti['nome']=products['Nome']
prodotti['prezzo']=products['Prezzo']
prodotti['categoria']=products['Categoria']
prodotti['assemblato']=False
prodotti['soglia']=products['Soglia']

prodotti
# Out:
#          id                                               nome  prezzo  \
# 0   5382198                     Esselunga Bio, kiwi biologici     4.98
# 1   5385170                   Esselunga Bio, meloni biologici     2.84
# 2   5381634                                  Lattuga Iceberg,     1.68
# 3   5391756           Esselunga Bio, peperoni rossi biologici     4.98
# 4   5837556                Esselunga, carciofi al vapore 250 g    2.88
# 5   5386477                    Esselunga, filetto di platessa    19.90
# 6   5735522              Esselunga, Sushi mix 4 porzioni 860 g   25.50
# 7   5772507                   Smart, Fish Burger salmone 240 g    3.59
# 8   5745336  Esselunga Hamburgeria, bovino adulto di razza ...    4.49
# 9   5534682          Amadori, hamburger ricetta classica 204 g    2.89
# 10  5428255  Esselunga Naturama, petto di pollo a fette all...   12.85
# 11  5388593                          Esselunga, pollo durelli     3.95
# ...

# %%
prodotti.to_csv('prodotti_finali.csv',index=False)
